# %%
from rembg import remove
from PIL import Image

# %%
s = 'sheep.jpeg'
# d = 'sheep.png'

img = Image.open(s)
output = remove(img)
# Out:
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 78.6GB/s]

# %%
output
# Out:
# <PIL.Image.Image image mode=RGBA size=300x168>

# %%
s = 'paris.jpg'
# d = 'sheep.png'

img = Image.open(s)
output = remove(img)

# %%
output
# Out:
# <PIL.Image.Image image mode=RGBA size=384x260>

# %%
s = 'redgirl.jpeg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=259x194>

# %%
s = 'gorilla.jpeg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=190x266>

# %%
s = 'work.jpeg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=750x500>

# %%
s = 's.jpeg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=275x183>

# %%
s = 'sa.png'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=367x137>

# %%
s = 'om.jpeg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=300x168>

# %%
s = 'omw.jpg'

img = Image.open(s)
output = remove(img)
output
# Out:
# <PIL.Image.Image image mode=RGBA size=450x450>
